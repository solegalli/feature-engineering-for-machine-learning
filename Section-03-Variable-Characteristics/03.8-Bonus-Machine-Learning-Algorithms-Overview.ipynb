# %% [markdown]
# ## Bonus: Machine Learning Algorithms Overview
#
# Table illustrating the advantages and disadvantages of the different Machine Learning algorithms, as well as their requirements in terms of feature engineering, and common applications.

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
PATH = "../ML_Comparison.png"
Image(filename = PATH , width=1000, height=10000)
