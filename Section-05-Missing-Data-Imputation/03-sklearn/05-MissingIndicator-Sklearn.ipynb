# %% [markdown]
# ## Adding  Missing Indicators with Scikit-learn ==> MissingIndicator
#
# [Feature Engineering for Machine Learning Course](https://www.trainindata.com/p/feature-engineering-for-machine-learning)
#
# Scikit-learn provides the **MissingIndicator** class to add a binary variable that highlight NA.
#
# The MissingIndicator has the option of adding a Missing indicators to all the variables in the dataset, or only to those that show NA in the train set.
#
# ### Attention!
#
# The transformer only returns the binary variables, which need to be added to the original train data.
#
# ### More details about the transformers
#
# - [MissingIndicator](https://scikit-learn.org/stable/modules/generated/sklearn.impute.MissingIndicator.html)
#
#
# ## In this demo:
#
# We will add a Missing Indicator to the variables of the Ames House Price Dataset
#
# - To download the dataset please refer to the lecture **Datasets** in **Section 2** of this course.

# %%
import pandas as pd

from sklearn.impute import SimpleImputer, MissingIndicator

from sklearn.model_selection import train_test_split

# %%
# We use only the following variables for the demo,
# containing a mix of categorical and numerical features.

cols_to_use = [
    "BsmtQual",
    "FireplaceQu",
    "MSZoning",
    "BsmtUnfSF",
    "LotFrontage",
    "MasVnrArea",
    "Street",
    "Alley",
    "SalePrice",
]

# %%
# let's load the House Prices dataset

data = pd.read_csv("../../Datasets/houseprice.csv", usecols=cols_to_use)

data.head()
# Out:
#   MSZoning  LotFrontage Street Alley  MasVnrArea BsmtQual  BsmtUnfSF  \
# 0       RL         65.0   Pave   NaN       196.0       Gd        150
# 1       RL         80.0   Pave   NaN         0.0       Gd        284
# 2       RL         68.0   Pave   NaN       162.0       Gd        434
# 3       RL         60.0   Pave   NaN         0.0       TA        540
# 4       RL         84.0   Pave   NaN       350.0       Gd        490
#
#   FireplaceQu  SalePrice
# 0         NaN     208500
# 1          TA     181500
# 2          TA     223500
# 3          Gd     140000
# 4          TA     250000

# %%
# let's separate into training and testing set

X_train, X_test, y_train, y_test = train_test_split(
    data.drop("SalePrice", axis=1),  # just the features
    data["SalePrice"],  # the target
    test_size=0.3,  # the percentage of obs in the test set
    random_state=0,  # for reproducibility
)

X_train.shape, X_test.shape
# Out:
# ((1022, 8), (438, 8))

# %%
# let's check the misssing data again
X_train.isnull().mean()
# Out:
# MSZoning       0.000000
# LotFrontage    0.184932
# Street         0.000000
# Alley          0.939335
# MasVnrArea     0.004892
# BsmtQual       0.023483
# BsmtUnfSF      0.000000
# FireplaceQu    0.467710
# dtype: float64

# %% [markdown]
# ## Add Missing Indicators

# %%
indicator = MissingIndicator(
    error_on_new=True,
    features="missing-only",
)

indicator.fit(X_train)
# Out:
# MissingIndicator()

# %%
# We can see the features that contained NA.
# The result shows the index of the columns.

indicator.features_
# Out:
# array([1, 3, 4, 5, 7], dtype=int64)

# %%
# we can find the feature names by passing the index to the
# list of columns

X_train.columns[indicator.features_]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrArea', 'BsmtQual', 'FireplaceQu'], dtype='object')

# %%
# the indicator returns only the additional indicators
# when we transform the dataset

tmp = indicator.transform(X_train)

tmp
# Out:
# array([[ True,  True, False, False,  True],
#        [ True,  True, False, False, False],
#        [False,  True, False, False,  True],
#        ...,
#        [False,  True, False,  True,  True],
#        [ True,  True, False, False, False],
#        [False,  True, False, False,  True]])

# %%
# variable names for the indicators come out of the box

indicator.get_feature_names_out()
# Out:
# array(['missingindicator_LotFrontage', 'missingindicator_Alley',
#        'missingindicator_MasVnrArea', 'missingindicator_BsmtQual',
#        'missingindicator_FireplaceQu'], dtype=object)

# %%
# so we need to join them manually to the original X_train

# and now we concatenate the indicators
X_train = pd.concat(
    [
        X_train.reset_index(),
        pd.DataFrame(tmp, columns=indicator.get_feature_names_out()),
    ],
    axis=1,
)

X_train.head()
# Out:
#    index MSZoning  LotFrontage Street Alley  MasVnrArea BsmtQual  BsmtUnfSF  \
# 0     64       RL          NaN   Pave   NaN       573.0       Gd        318
# 1    682       RL          NaN   Pave   NaN         0.0       Gd        288
# 2    960       RL         50.0   Pave   NaN         0.0       TA        162
# 3   1384       RL         60.0   Pave   NaN         0.0       TA        356
# 4   1100       RL         60.0   Pave   NaN         0.0       TA          0
#
#   FireplaceQu  missingindicator_LotFrontage  missingindicator_Alley  \
# 0         NaN                          True                    True
# 1          Gd                          True                    True
# 2         NaN                         False                    True
# 3         NaN                         False                    True
# 4         NaN                         False                    True
#
#    missingindicator_MasVnrArea  missingindicator_BsmtQual  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
#
#    missingindicator_FireplaceQu
# 0                          True
# 1                         False
# 2                          True
# 3                          True
# 4                          True

# %%
# now the same for the test set
tmp = indicator.transform(X_test)

X_test = pd.concat(
    [
        X_test.reset_index(),
        pd.DataFrame(tmp, columns=indicator.get_feature_names_out()),
    ],
    axis=1,
)

X_test.head()
# Out:
#    index MSZoning  LotFrontage Street Alley  MasVnrArea BsmtQual  BsmtUnfSF  \
# 0    529       RL          NaN   Pave   NaN         NaN       TA        816
# 1    491       RL         79.0   Pave   NaN         0.0       TA        238
# 2    459       RL          NaN   Pave   NaN       161.0       TA        524
# 3    279       RL         83.0   Pave   NaN       299.0       Gd        768
# 4    655       RM         21.0   Pave   NaN       381.0       TA        525
#
#   FireplaceQu  missingindicator_LotFrontage  missingindicator_Alley  \
# 0          TA                          True                    True
# 1          TA                         False                    True
# 2          TA                          True                    True
# 3          TA                         False                    True
# 4         NaN                         False                    True
#
#    missingindicator_MasVnrArea  missingindicator_BsmtQual  \
# 0                         True                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
#
#    missingindicator_FireplaceQu
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                          True

# %% [markdown]
# ## Add indicators with the SimpleImputer
#
# The simple imputer has the option to add indicators straightaway.

# %%
# let's separate into training and testing set

X_train, X_test, y_train, y_test = train_test_split(
    data.drop("SalePrice", axis=1),  # just the features
    data["SalePrice"],  # the target
    test_size=0.3,  # the percentage of obs in the test set
    random_state=0,  # for reproducibility
)

# %%
# We impute features with the most frequent value for
# simplicity to showcase how we can add indicators with
# the simple Imputer:

imputer = SimpleImputer(
    strategy="most_frequent",
    add_indicator=True,
).set_output(transform="pandas")

# we fit the imputer to the train set
# the imputer will learn the mode of all variables
imputer.fit(X_train)
# Out:
# SimpleImputer(add_indicator=True, strategy='most_frequent')

# %%
# we can look at the frequent values like this:

imputer.statistics_
# Out:
# array(['RL', 60.0, 'Pave', 'Pave', 0.0, 'TA', 0, 'Gd'], dtype=object)

# %% [markdown]
# **Note** that the transformer learns the most frequent value for both categorical AND numerical variables.

# %%
# and now we impute the train and test set

# NOTE: the data is returned as a numpy array!!!

X_train = imputer.transform(X_train)
X_test = imputer.transform(X_test)

X_train
# Out:
#      MSZoning LotFrontage Street Alley MasVnrArea BsmtQual BsmtUnfSF  \
# 64         RL        60.0   Pave  Pave      573.0       Gd       318
# 682        RL        60.0   Pave  Pave        0.0       Gd       288
# 960        RL        50.0   Pave  Pave        0.0       TA       162
# 1384       RL        60.0   Pave  Pave        0.0       TA       356
# 1100       RL        60.0   Pave  Pave        0.0       TA         0
# ...       ...         ...    ...   ...        ...      ...       ...
# 763        RL        82.0   Pave  Pave      673.0       Gd        89
# 835        RL        60.0   Pave  Pave        0.0       Gd       625
# 1216       RM        68.0   Pave  Pave        0.0       TA         0
# 559        RL        60.0   Pave  Pave       18.0       Gd      1374
# 684        RL        58.0   Pave  Pave       30.0       Gd      1195
#
#      FireplaceQu missingindicator_LotFrontage missingindicator_Alley  \
# 64            Gd                         True                   True
# 682           Gd                         True                   True
# 960           Gd                        False                   True
# 1384          Gd                        False                   True
# 1100          Gd                        False                   True
# ...          ...                          ...                    ...
# 763           Gd                        False                   True
# 835           Gd                        False                   True
# 1216          Gd                        False                   True
# 559           TA                         True                   True
# 684           Gd                        False                   True
#
#      missingindicator_MasVnrArea missingindicator_BsmtQual  \
# 64                         False                     False
# 682                        False                     False
# 960                        False                     False
# 1384                       False                     False
# 1100                       False                     False
# ...                          ...                       ...
# 763                        False                     False
# 835                        False                     False
# 1216                       False                      True
# 559                        False                     False
# 684                        False                     False
#
#      missingindicator_FireplaceQu
# 64                           True
# 682                         False
# 960                          True
# 1384                         True
# 1100                         True
# ...                           ...
# 763                         False
# 835                          True
# 1216                         True
# 559                         False
# 684                          True
#
# [1022 rows x 13 columns]
