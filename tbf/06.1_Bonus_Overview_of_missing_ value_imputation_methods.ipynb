# %% [markdown]
# ## Overview of missing value imputation methods
#
# Table illustrating the advantages and disadvantages of the different missing value imputation methods

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
PATH = "NA_methods_Comparison.jpg"
Image(filename = PATH , width=1000, height=10000)
